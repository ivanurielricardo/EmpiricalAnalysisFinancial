# %%
# import the necessary modules

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# load the data. Make sure its in the same folder as the notebook

tweets = pd.read_csv('fin_tweets_sentiment.csv')
tweets.head()
# Out:
#             id                                               text  \
# 0   1.0197E+18  VIDEO: “I was in my office. I was minding my o...
# 1  1.01971E+18  The price of lumber $LB_F is down 22% since hi...
# 2  1.01971E+18  Who says the American Dream is dead? https://t...
# 3  1.01972E+18  Barry Silbert is extremely optimistic on bitco...
# 4  1.01972E+18  How satellites avoid attacks and space junk wh...
#
#                         timestamp        source symbols      company_names  \
# 0  Wed Jul 18 21:33:26 +0000 2018  GoldmanSachs      GS  The Goldman Sachs
# 1  Wed Jul 18 22:22:47 +0000 2018    StockTwits       M             Macy's
# 2  Wed Jul 18 22:32:01 +0000 2018     TheStreet     AIG           American
# 3  Wed Jul 18 22:52:52 +0000 2018   MarketWatch     BTC            Bitcoin
# 4  Wed Jul 18 23:00:01 +0000 2018        Forbes    ORCL             Oracle
#
#                                                  url verified
# 0  https://twitter.com/i/web/status/1019696670777...     TRUE
# 1  https://twitter.com/i/web/status/1019709091038...     TRUE
# 2                            https://buff.ly/2L3kmc4     TRUE
# 3  https://twitter.com/i/web/status/1019716662587...     TRUE
# 4                     http://on.forbes.com/6013DqDDU     TRUE

# %%
# create a cleaner for tweets

import re

def cleantext(text):
    
    # Remove URLs
    text = re.sub('(http|ftp|https)[^\s]*', '', text)
    # Removes account handles
    text = re.sub('@[^\s]*', '', text)
    # Removes emails
    text = re.sub('[^\s]+@[^\s]\.\[^\s]+', '', text)
    # Remove strings with numbers
    text = re.sub('[^\s]*[0-9]+[^\s]*', '', text)
    
    return text

# Test on a couple of tweets
sel = [23, 45,67,345,8762]

for i in sel:
  print("===================")
  print(tweets.text[i])
  print(cleantext(tweets.text[i]))

# Get the text of the tweets

tweets['cleantweets'] = tweets['text'].apply(cleantext)
tweets.head()
# Out:
# ===================
# EBay revenue misses as weak U.S. sporting season hits StubHub https://t.co/3RdnkMVUn8 https://t.co/N6iXpxEZjG
# EBay revenue misses as weak U.S. sporting season hits StubHub
# ===================
# $2.29 Billion in Sales Expected for Mosaic Co $MOS This Quarter https://t.co/TvQE3lexlH
#  Billion in Sales Expected for Mosaic Co $MOS This Quarter
# ===================
# RT @MttsTrading: MTTS WEEKLY WATCHLIST FOR JULY 9TH 2018 $CXO $HP $RSPP https://t.co/poc5zDyb4j
# RT  MTTS WEEKLY WATCHLIST FOR JULY   $CXO $HP $RSPP
# ===================
# $AWR $BKH $CNP $DTE $EIX $EXC $MDU $NI $NJR $PPL $SCG $SR $SRE $SWX $UGI $XLU https://t.co/gseVPlDcgg
# $AWR $BKH $CNP $DTE $EIX $EXC $MDU $NI $NJR $PPL $SCG $SR $SRE $SWX $UGI $XLU
# ===================
# RT @PowerrTrader: Preliminary List of Setups: $CVEO $ROKU $CAKE $BURL $BBY $RH $AXGN $STAA $GTS $ALDR $CRSP $MDGL $TPIV $VKTX $VRTX $AYX $S…
# RT  Preliminary List of Setups: $CVEO $ROKU $CAKE $BURL $BBY $RH $AXGN $STAA $GTS $ALDR $CRSP $MDGL $TPIV $VKTX $VRTX $AYX $S…
#             id                                               text  \
# 0   1.0197E+18  VIDEO: “I was in my office. I was minding my o...
# 1  1.01971E+18  The price of lumber $LB_F is down 22% since hi...
# 2  1.01971E+18  Who says the American Dream is dead? https://t...
# 3  1.01972E+18  Barry Silbert is extremely optimistic on bitco...
# 4  1.01972E+18  How satellites avoid attacks and space junk wh...
#
#                         timestamp        source symbols      company_names  \
# 0  Wed Jul 18 21:33:26 +0000 2018  GoldmanSachs      GS  The Goldman Sachs
# 1  Wed Jul 18 22:22:47 +0000 2018    StockTwits       M             Macy's
# 2  Wed Jul 18 22:32:01 +0000 2018     TheStreet     AIG           American
# 3  Wed Jul 18 22:52:52 +0000 2018   MarketWatch     BTC            Bitcoin
# 4  Wed Jul 18 23:00:01 +0000 2018        Forbes    ORCL             Oracle
#
#                                                  url verified  \
# 0  https://twitter.com/i/web/status/1019696670777...     TRUE
# 1  https://twitter.com/i/web/status/1019709091038...     TRUE
# 2                            https://buff.ly/2L3kmc4     TRUE
# 3  https://twitter.com/i/web/status/1019716662587...     TRUE
# 4                     http://on.forbes.com/6013DqDDU     TRUE
#
#                                          cleantweets
# 0  VIDEO: “I was in my office. I was minding my o...
# 1  The price of lumber $LB_F is down  since hitti...
# 2              Who says the American Dream is dead?
# 3  Barry Silbert is extremely optimistic on bitco...
# 4  How satellites avoid attacks and space junk wh...

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /Users/Ivan/opt/anaconda3/lib/python3.9/site-packages (3.3.2)
# Requirement already satisfied: requests in /Users/Ivan/opt/anaconda3/lib/python3.9/site-packages (from vaderSentiment) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Ivan/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/Ivan/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Ivan/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Ivan/opt/anaconda3/lib/python3.9/site-packages (from requests->vaderSentiment) (3.2)

# %%
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def sentiment_scores(sentence):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
    print("Overall sentiment dictionary is : ", sentiment_dict)
    print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative")
    print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral")
    print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive")
 
    print("Sentence Overall Rated As", end = " ")
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        print("Positive")
 
    elif sentiment_dict['compound'] <= - 0.05 :
        print("Negative")
 
    else :
        print("Neutral")

# %%
sentence = tweets.cleantweets[5676]
print(sentence)
# Out:
# Short sale volume (not short interest) for $SDS on  is   $VALE  $MCHP  $KDP  $RHT

# %%
sentiment_scores(sentence)
# Out:
# Overall sentiment dictionary is :  {'neg': 0.16, 'neu': 0.84, 'pos': 0.0, 'compound': -0.357}
# sentence was rated as  16.0 % Negative
# sentence was rated as  84.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative

# %%
# Sentiment Scores

def neg_raw_sentiment_scores(text):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(text)
    return sentiment_dict['neg']

def pos_raw_sentiment_scores(text):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(text)
    return sentiment_dict['pos']

def neu_raw_sentiment_scores(text):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(text)
    return sentiment_dict['neu']

# %%
tweets['positive'] = tweets['cleantweets'].apply(pos_raw_sentiment_scores)
tweets['negative'] = tweets['cleantweets'].apply(neg_raw_sentiment_scores)
tweets['neutral'] = tweets['cleantweets'].apply(neu_raw_sentiment_scores)
tweets.head()
# Out:
#             id                                               text  \
# 0   1.0197E+18  VIDEO: “I was in my office. I was minding my o...
# 1  1.01971E+18  The price of lumber $LB_F is down 22% since hi...
# 2  1.01971E+18  Who says the American Dream is dead? https://t...
# 3  1.01972E+18  Barry Silbert is extremely optimistic on bitco...
# 4  1.01972E+18  How satellites avoid attacks and space junk wh...
#
#                         timestamp        source symbols      company_names  \
# 0  Wed Jul 18 21:33:26 +0000 2018  GoldmanSachs      GS  The Goldman Sachs
# 1  Wed Jul 18 22:22:47 +0000 2018    StockTwits       M             Macy's
# 2  Wed Jul 18 22:32:01 +0000 2018     TheStreet     AIG           American
# 3  Wed Jul 18 22:52:52 +0000 2018   MarketWatch     BTC            Bitcoin
# 4  Wed Jul 18 23:00:01 +0000 2018        Forbes    ORCL             Oracle
#
#                                                  url verified  \
# 0  https://twitter.com/i/web/status/1019696670777...     TRUE
# 1  https://twitter.com/i/web/status/1019709091038...     TRUE
# 2                            https://buff.ly/2L3kmc4     TRUE
# 3  https://twitter.com/i/web/status/1019716662587...     TRUE
# 4                     http://on.forbes.com/6013DqDDU     TRUE
#
#                                          cleantweets  positive  negative  \
# 0  VIDEO: “I was in my office. I was minding my o...     0.000     0.000
# 1  The price of lumber $LB_F is down  since hitti...     0.000     0.000
# 2              Who says the American Dream is dead?      0.177     0.381
# 3  Barry Silbert is extremely optimistic on bitco...     0.091     0.000
# 4  How satellites avoid attacks and space junk wh...     0.000     0.338
#
#    neutral
# 0    1.000
# 1    1.000
# 2    0.442
# 3    0.909
# 4    0.662
